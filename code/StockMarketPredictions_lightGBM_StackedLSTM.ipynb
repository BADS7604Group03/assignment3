# %% [markdown]
# <a href="https://colab.research.google.com/github/BADS7604Group03/assignment3/blob/main/code/StockMarketPredictions_lightGBM_StackedLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set Environment

# %%
# List all NVIDIA GPUs as avaiable in this computer (or colub's session)
# !nvidia-smi -L
# Out:
# GPU 0: Tesla V100-SXM2-16GB (UUID: GPU-29c1d0fb-d6a2-dc0d-197b-ea9c2b1bd39b)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sys,os,time,datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
# %matplotlib inline
print(f"Python {sys.version}")
print(f"NumPy {np.__version__}")
print(f"tf.keras.backend.image_data_format() = {tf.keras.backend.image_data_format()}")
gpus = tf.config.list_physical_devices('GPU')
print(f"Tensorflow detected : {len(gpus)} GPU(s)")
for i,gpu in enumerate(gpus):
  print(f" GPU No. {i} : Name = {gpu.name} , Type = {gpu.device_type}")
# Out:
# Python 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# NumPy 1.21.5
# tf.keras.backend.image_data_format() = channels_last
# Tensorflow detected : 1 GPU(s)
#  GPU No. 0 : Name = /physical_device:GPU:0 , Type = GPU

# %% [markdown]
# # Import data

# %%
file = "1AA_1WKPuI4wXQGKTxoMzf3tPrT47jq1P"
dwn_url=f"https://drive.google.com/uc?export=download&id={file}"
dfstok = pd.read_excel(dwn_url ,sheet_name='Daily')
dfstok = dfstok.sort_values(by='Date').reset_index(drop=True)
print(f"Shape of dfstock : {dfstok.shape}")
display(dfstok.head(2))
# Out:
# Shape of dfstock : (2469, 6)
#         Date  Close  Open  High   Low   Volume
# 0 2012-02-09   5.60  5.64  5.64  5.60  4118750
# 1 2012-02-10   5.64  5.56  5.64  5.52  6783500

# %%
dfstok['return_close'] = dfstok.Close.diff(-1)/dfstok.Close
dfstok.head()
# Out:
#         Date  Close  Open  High   Low   Volume  return_close
# 0 2012-02-09   5.60  5.64  5.64  5.60  4118750     -0.007143
# 1 2012-02-10   5.64  5.56  5.64  5.52  6783500      0.014184
# 2 2012-02-13   5.56  5.64  5.64  5.56  1923000      0.014388
# 3 2012-02-14   5.48  5.60  5.60  5.44  3553750     -0.007299
# 4 2012-02-15   5.52  5.48  5.56  5.48  2479125      0.000000

# %% [markdown]
# # Explore data

# %%
plt.figure(figsize = (15,5))
plt.plot(range(dfstok.shape[0]),dfstok['Close'])
plt.title('Close price')
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.plot(dfstok['return_close'].diff())
plt.title('Close price diff')
plt.show()

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## Create Sequence feature

# %%
def window_return(val, window):
  lst_x = []
  lst_y = []
  lst_x_return = []
  lst_y_return = []
  for i in range(0,len(val) - window -1,1):
    first_price = val[i]
    lst_x.append(val[i:i+window])
    lst_y.append(val[i+window])
    lst_x_return.append((val[i+1:i+window]-first_price)/first_price)
    lst_y_return.append((val[i+window]-first_price)/first_price)
  array_x_return = np.array(lst_x_return).reshape(-1,window-1)
  array_y_return = np.array(lst_y_return).reshape(-1,1)
  array_x = np.array(lst_x).reshape(-1,window)
  array_y = np.array(lst_y).reshape(-1,1)
  return array_x,array_x_return,array_y,array_y_return

# %%
x_close,x_return,y_close,y_return = window_return(dfstok.Close.values, 20)
print(f"x_close.shape : {x_close.shape}")
print(f"x_return.shape : {x_return.shape}")
print(f"y_close.shape : {y_close.shape}")
print(f"y_return.shape : {y_return.shape}")
# Out:
# x_close.shape : (2448, 20)
# x_return.shape : (2448, 19)
# y_close.shape : (2448, 1)
# y_return.shape : (2448, 1)

# %% [markdown]
# ## Split Train/Test Data set

# %%
def split(x_array, y_array, ratio_train=0.8, ratio_test=0.1):
  n_data = x_array.shape[0]
  n_train = int(n_data * ratio_train)    
  n_test = int(n_data *ratio_test)       
  n_val = n_data -n_train -n_test

  x_train, y_train = x_array[:n_train], y_array[:n_train] 
  x_val, y_val      = x_array[n_train:n_train+n_val], y_array[n_train:n_train+n_val]
  x_test, y_test   = x_array[n_train+n_val:], y_array[n_train+n_val:]
  return [x_train, x_val, x_test], [y_train, y_val, y_test]

# %%
# Split data tuples x-(train, val, test), y-(train, val, test)
lst_x_close ,lst_y_close = split(x_close, y_close, 0.8, 0.1)
lst_x_return ,lst_y_return = split(x_return, y_return, 0.8, 0.1)

# %%
print(f"Shape Price:{lst_x_close[0].shape} ,Val:{lst_x_close[1].shape}, Test:{lst_x_close[2].shape}")
print(f"Shape Return:{lst_x_return[0].shape} ,Val:{lst_x_return[1].shape}, Test:{lst_x_return[2].shape}")
# Out:
# Shape Price:(1958, 20) ,Val:(246, 20), Test:(244, 20)
# Shape Return:(1958, 19) ,Val:(246, 19), Test:(244, 19)

# %%
print(f"Shape Price:{lst_y_close[0].shape} ,Val:{lst_y_close[1].shape}, Test:{lst_y_close[2].shape}")
print(f"Shape Return:{lst_y_return[0].shape} ,Val:{lst_y_return[1].shape}, Test:{lst_y_return[2].shape}")
# Out:
# Shape Price:(1958, 1) ,Val:(246, 1), Test:(244, 1)
# Shape Return:(1958, 1) ,Val:(246, 1), Test:(244, 1)

# %% [markdown]
# ## Normalize Data form train data set

# %%
#Fit Normalize tools
norm_tool = MinMaxScaler().fit(lst_x_return[0].reshape(-1,1))

# %%
def norm_val(norm_fn, lst_x, lst_y):
  return_x = [i for i in lst_x ]
  return_y = [i for i in lst_y ]
  for i in range(len(lst_x)):
    return_x[i] = norm_fn.transform(lst_x[i].reshape(-1,1)).reshape(lst_x[i].shape)
    return_y[i] = norm_fn.transform(lst_y[i].reshape(-1,1)).reshape(lst_y[i].shape)
  return return_x, return_y

# %%
lst_x_norm   ,lst_y_norm= norm_val(norm_tool, lst_x_return, lst_y_return)
print(f"Shape x:{lst_x_norm[0].shape} ,Val:{lst_x_norm[1].shape}, Test:{lst_x_norm[2].shape}")
print(f"Shape y:{lst_y_norm[0].shape} ,Val:{lst_y_norm[1].shape}, Test:{lst_y_norm[2].shape}")
# Out:
# Shape x:(1958, 19) ,Val:(246, 19), Test:(244, 19)
# Shape y:(1958, 1) ,Val:(246, 1), Test:(244, 1)

# %% [markdown]
# ## Create data train - validate - test ( Size , Time  , Feature)

# %%
#Create x array
x_train_norm = lst_x_norm[0]
x_val_norm   = lst_x_norm[1]
x_test_norm  = lst_x_norm[2]

# %%
#Create y array
y_train_norm = lst_y_norm[0]
y_val_norm   = lst_y_norm[1]
y_test_norm  = lst_y_norm[2]
y_test = lst_y_close[2]

# %%
print(f"\n x_train_norm.shape {x_train_norm.shape}{y_train_norm.shape} \n{x_train_norm[0]} -->y= {y_train_norm[0]}")
print(f"\n x_val_norm.shape {x_val_norm.shape}{y_val_norm.shape} \n{x_val_norm[0]} -->y={y_val_norm[0]}")
print(f"\n x_test_norm.shape {x_test_norm.shape}{y_test_norm.shape}\n{x_test_norm[0]} ")
# Out:
#  x_train_norm.shape (1958, 19)(1958, 1)
# [0.45923102 0.43481383 0.41039664 0.42260524 0.42260524 0.42260524
#  0.39818805 0.37377085 0.38597945 0.38597945 0.41039664 0.38597945
#  0.42260524 0.44702243 0.47143962 0.47143962 0.45923102 0.42260524
#  0.45923102] -->y= [0.48364822]
#
#  x_val_norm.shape (246, 19)(246, 1)
# [0.43599531 0.43599531 0.40291395 0.39188683 0.39188683 0.39188683
#  0.34777836 0.314697   0.1933987  0.25956141 0.18237158 0.18237158
#  0.22648005 0.25956141 0.29264277 0.24853429 0.23750717 0.21545294
#  0.17134446] -->y=[-0.02714368]
#
#  x_test_norm.shape (244, 19)(244, 1)
# [0.43515296 0.42328349 0.41141402 0.38767509 0.37580562 0.43515296
#  0.39954456 0.44702243 0.4588919  0.4588919  0.44702243 0.48263083
#  0.4945003  0.4588919  0.4588919  0.51823924 0.54197817 0.56571711
#  0.54197817]

# %% [markdown]
# ## Convert to float32

# %%
x_train_norm = x_train_norm.astype(np.float32)
y_train_norm = y_train_norm.astype(np.float32)
x_val_norm = x_val_norm.astype(np.float32)
y_val_norm = y_val_norm.astype(np.float32)
x_test_norm = x_test_norm.astype(np.float32)
y_test_norm = y_test_norm.astype(np.float32)

# %% [markdown]
# # LightGBM Regression

# %%
import lightgbm as lgb

# %%
#Prepare Model
dtrain = lgb.Dataset(x_train_norm, label=y_train_norm.ravel() )
dvalidate = lgb.Dataset(x_val_norm, label=y_val_norm.ravel() )

# %%
from traitlets.traitlets import Tuple
params = {
          'boosting_type': 'gbdt',
          'objective': 'regression',
          'metric':'l2',
          'num_leaves':10,
          'max_depth':5,
          'drop_rate ':0.3,
          'reg_sqrt':True,
          'boost_from_average':True,
          'learning_rate': 0.0001,
          'verbose': 0,
         }

# %%
#Run Model
start_tm = time.time()
evals_results = {}
model_lgbm = lgb.train(params, 
                  train_set =dtrain, 
                  valid_sets=dvalidate,
                  evals_result=evals_results, 
                  num_boost_round=1000, #iterations
                  early_stopping_rounds=100,
                  verbose_eval=50, 
                  feval=None)
print(f">>>>> Training Time >>>> {time.time() - start_tm} seconds")
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's l2: 0.0218317
# [100]	valid_0's l2: 0.0216318
# [150]	valid_0's l2: 0.0214341
# [200]	valid_0's l2: 0.0212385
# [250]	valid_0's l2: 0.021045
# [300]	valid_0's l2: 0.0208537
# [350]	valid_0's l2: 0.0206645
# [400]	valid_0's l2: 0.0204772
# [450]	valid_0's l2: 0.0202918
# [500]	valid_0's l2: 0.0201085
# [550]	valid_0's l2: 0.0199271
# [600]	valid_0's l2: 0.0197476
# [650]	valid_0's l2: 0.01957
# [700]	valid_0's l2: 0.0193943
# [750]	valid_0's l2: 0.0192205
# [800]	valid_0's l2: 0.0190485
# [850]	valid_0's l2: 0.0188784
# [900]	valid_0's l2: 0.0187095
# [950]	valid_0's l2: 0.0185418
# [1000]	valid_0's l2: 0.0183759
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 0.0183759
# >>>>> Training Time >>>> 1.1658804416656494 seconds

# %%
lgbm_preds_norm = model_lgbm.predict(x_test_norm).reshape(-1, 1)
lgbm_preds = norm_tool.inverse_transform(lgbm_preds_norm)
lgbm_price = (lst_x_close[2][:,0].reshape(-1,1)*(1+lgbm_preds)) # Return --> Price from P-20 x (1+return)
true_price = lst_y_close[2]

# %%
#Plot training and validation loss values
plt.figure(figsize=(15,5))
plt.plot( lgbm_price)
plt.plot( true_price)
plt.title('Compare result on test set')
plt.ylabel('Price')
plt.xlabel('Time')
plt.legend(['Predict','True'], loc='upper right')
plt.show()

# %%
mse  = mean_squared_error(true_price,lgbm_price)
mae  = mean_absolute_error(true_price,lgbm_price)

print(f"mean_squared_error : {mse}")
print(f"mean_absolute_error : {mae}")
# Out:
# mean_squared_error : 3.3080337413185377
# mean_absolute_error : 1.514661444117051

# %%
move_avg = lst_x_close[2].mean(axis=1).reshape(-1, 1)
mse  = mean_squared_error(true_price,move_avg)
mae  = mean_absolute_error(true_price,move_avg)
print(f"mean_squared_error : {mse}")
print(f"mean_absolute_error : {mae}")
# Out:
# mean_squared_error : 1.3282297643442618
# mean_absolute_error : 0.9416803278688523

# %%
pd.set_option('display.max_rows', 500)

pd.DataFrame({"price_t20":lst_x_close[2][:,-1].ravel()
              ,"true_price_t21":true_price.ravel()
              ,"lgbm_price":lgbm_price.ravel()
              ,"move_avg":move_avg.ravel()})
# Out:
#      price_t20  true_price_t21  lgbm_price  move_avg
# 0        15.20           15.20   14.569651   14.5050
# 1        15.20           15.20   14.470823   14.5450
# 2        15.20           15.20   14.369628   14.5900
# 3        15.20           15.00   14.272980   14.6400
# 4        15.00           14.80   14.070526   14.6850
# 5        14.80           14.90   13.964850   14.7300
# 6        14.90           14.90   14.453666   14.7850
# 7        14.90           15.00   14.167239   14.8150
# 8        15.00           14.70   14.554740   14.8650
# 9        14.70           14.90   14.617433   14.8800
# 10       14.90           14.80   14.617433   14.9000
# 11       14.80           14.70   14.516623   14.9150
# 12       14.70           14.60   14.772852   14.9300
# 13       14.60           15.20   14.873347   14.9250
# 14       15.20           16.10   14.670829   14.9450
# 15       16.10           16.60   14.752838   15.0250
# 16       16.60           16.90   15.261557   15.1300
# 17       16.90           17.00   15.465044   15.2250
# 18       17.00           16.80   15.668532   15.3150
# 19       16.80           16.70   15.465044   15.3850
# 20       16.70           16.60   15.409531   15.4600
# 21       16.60           17.70   15.386475   15.5300
# 22       17.70           19.10   15.470371   15.6550
# 23       19.10           18.60   15.352198   15.8500
# 24       18.60           18.40   15.147502   16.0300
# 25       18.40           18.50   15.249850   16.2100
# 26       18.50           18.10   15.249850   16.3900
# 27       18.10           18.20   15.352198   16.5500
# 28       18.20           18.30   15.045154   16.7100
# 29       18.30           18.40   15.249850   16.8900
# 30       18.40           18.20   15.147502   17.0650
# 31       18.20           18.20   15.045154   17.2350
# 32       18.20           18.20   14.942806   17.4100
# 33       18.20           18.20   15.556894   17.5900
# 34       18.20           18.40   16.380738   17.7400
# 35       18.40           18.40   16.889456   17.8550
# 36       18.40           18.20   17.107330   17.9450
# 37       18.20           19.30   17.203076   18.0100
# 38       19.30           19.60   17.092944   18.1250
# 39       19.60           19.80   17.087397   18.2650
# 40       19.80           19.80   16.989766   18.4200
# 41       19.80           20.30   18.008637   18.5800
# 42       20.30           20.50   19.328162   18.7100
# 43       20.50           20.40   18.856399   18.7800
# 44       20.40           20.40   18.720843   18.8700
# 45       20.40           20.70   18.755021   18.9700
# 46       20.70           20.30   18.415612   19.0800
# 47       20.30           19.70   18.517356   19.1900
# 48       19.70           20.10   18.523301   19.2650
# 49       20.10           20.40   18.625732   19.3550
# 50       20.40           20.30   18.517356   19.4550
# 51       20.30           20.40   18.517356   19.5600
# 52       20.40           20.20   18.517356   19.6700
# 53       20.20           20.30   18.517356   19.7700
# 54       20.30           20.60   18.653642   19.8750
# 55       20.60           20.60   18.720843   19.9850
# 56       20.60           21.20   18.517356   20.0950
# 57       21.20           20.90   19.566049   20.2450
# 58       20.90           20.70   19.834134   20.3250
# 59       20.70           21.50   20.033270   20.3800
# 60       21.50           21.80   20.042908   20.4650
# 61       21.80           22.00   20.547706   20.5650
# 62       22.00           21.80   20.750146   20.6500
# 63       21.80           22.70   20.643691   20.7150
# 64       22.70           23.50   20.755717   20.8300
# 65       23.50           23.20   21.060948   20.9850
# 66       23.20           23.70   20.653974   21.1100
# 67       23.70           23.50   20.162553   21.2800
# 68       23.50           23.60   20.486985   21.4700
# 69       23.60           23.60   20.762867   21.6450
# 70       23.60           24.60   20.661088   21.8050
# 71       24.60           24.90   20.878989   22.0200
# 72       24.90           25.25   20.674293   22.2450
# 73       25.25           23.50   20.776641   22.4975
# 74       23.50           23.30   20.959205   22.6575
# 75       23.30           23.90   20.959205   22.7925
# 76       23.90           24.00   21.569667   22.9575
# 77       24.00           25.25   21.264436   23.0975
# 78       25.25           26.00   21.186033   23.3150
# 79       26.00           26.25   22.004817   23.5800
# 80       26.25           25.75   22.311861   23.8175
# 81       25.75           25.50   22.423566   24.0150
# 82       25.50           25.75   22.219716   24.1900
# 83       25.75           26.00   23.095823   24.3875
# 84       26.00           26.00   23.909772   24.5525
# 85       26.00           26.25   23.604541   24.6775
# 86       26.25           25.50   24.113260   24.8300
# 87       25.50           24.10   23.788300   24.9200
# 88       24.10           24.50   23.791132   24.9500
# 89       24.50           24.50   23.794629   24.9950
# 90       24.50           24.50   24.721915   25.0400
# 91       24.50           23.80   25.023402   25.0350
# 92       23.80           23.90   25.263178   24.9800
# 93       23.90           24.30   23.690322   24.9125
# 94       24.30           24.10   23.574504   24.9525
# 95       24.10           23.90   24.089552   24.9925
# 96       23.90           24.80   24.118942   24.9925
# 97       24.80           23.40   25.346727   25.0325
# 98       23.40           23.40   25.903369   24.9400
# 99       23.40           23.30   26.152440   24.8100
# 100      23.30           22.80   25.654298   24.6625
# 101      22.80           23.00   25.405227   24.5150
# 102      23.00           22.80   25.654298   24.3900
# 103      22.80           22.80   25.787749   24.2425
# 104      22.80           22.70   25.787749   24.0825
# 105      22.70           22.60   26.035708   23.9175
# 106      22.60           22.50   25.303410   23.7350
# 107      22.50           22.40   24.094117   23.5850
# 108      22.40           22.70   24.408944   23.5000
# 109      22.70           22.50   24.486867   23.4100
# 110      22.50           22.00   24.408944   23.3100
# 111      22.00           21.80   23.787242   23.1850
# 112      21.80           22.00   23.811174   23.0850
# 113      22.00           22.20   24.209687   22.9900
# 114      22.20           21.90   24.087081   22.8850
# 115      21.90           21.90   23.811174   22.7750
# 116      21.90           21.50   24.597545   22.6750
# 117      21.50           21.50   23.313032   22.5100
# 118      21.50           22.60   23.313032   22.4150
# 119      22.60           23.00   23.383439   22.3750
# 120      23.00           22.30   22.984652   22.3600
# 121      22.30           22.40   23.082365   22.3350
# 122      22.40           22.30   22.912995   22.3050
# 123      22.30           22.10   22.887341   22.2800
# 124      22.10           21.60   22.781291   22.2450
# 125      21.60           21.50   22.611795   22.1900
# 126      21.50           21.60   22.511742   22.1350
# 127      21.60           21.40   22.411690   22.0900
# 128      21.40           21.20   22.711847   22.0400
# 129      21.20           20.90   22.511742   21.9650
# 130      20.90           21.00   22.011481   21.8850
# 131      21.00           20.80   21.811377   21.8350
# 132      20.80           20.40   22.011481   21.7850
# 133      20.40           20.60   22.117492   21.7050
# 134      20.60           20.50   21.911429   21.6250
# 135      20.50           20.60   21.894654   21.5550
# 136      20.60           20.40   21.511220   21.4900
# 137      20.40           20.40   21.511220   21.4350
# 138      20.40           20.30   22.516005   21.3800
# 139      20.30           20.40   22.812239   21.2650
# 140      20.40           21.10   22.217120   21.1350
# 141      21.10           20.60   22.411690   21.0750
# 142      20.60           20.60   22.288046   20.9850
# 143      20.60           20.50   22.088153   20.9000
# 144      20.50           20.30   21.611273   20.8200
# 145      20.30           20.40   21.511220   20.7550
# 146      20.40           20.30   21.611273   20.7000
# 147      20.30           20.30   21.411168   20.6350
# 148      20.30           20.20   21.211064   20.5800
# 149      20.20           19.80   20.974845   20.5300
# 150      19.80           20.20   21.010960   20.4750
# 151      20.20           20.20   20.874487   20.4350
# 152      20.20           19.90   20.501101   20.4050
# 153      19.90           20.20   20.673770   20.3800
# 154      20.20           20.20   20.601596   20.3600
# 155      20.20           20.40   20.678914   20.3450
# 156      20.40           20.40   20.501101   20.3350
# 157      20.40           20.40   20.501101   20.3350
# 158      20.40           20.00   20.400605   20.3350
# 159      20.00           19.90   20.478148   20.3200
# 160      19.90           20.10   21.111012   20.2950
# 161      20.10           19.90   20.673770   20.2450
# 162      19.90           20.00   20.673770   20.2100
# 163      20.00           19.90   20.573412   20.1800
# 164      19.90           19.80   20.377765   20.1500
# 165      19.80           20.00   20.473054   20.1250
# 166      20.00           20.90   20.400605   20.1050
# 167      20.90           21.70   20.464406   20.1350
# 168      21.70           21.40   20.446486   20.2050
# 169      21.40           21.50   20.042908   20.2650
# 170      21.50           21.70   20.441302   20.3500
# 171      21.70           21.00   20.446486   20.4250
# 172      21.00           20.40   20.134448   20.4650
# 173      20.40           20.00   20.363596   20.4900
# 174      20.00           19.90   20.300109   20.4800
# 175      19.90           19.80   20.473054   20.4650
# 176      19.80           19.70   20.473054   20.4350
# 177      19.70           19.40   20.473054   20.4000
# 178      19.40           19.60   20.071622   20.3500
# 179      19.60           19.60   19.998623   20.3300
# 180      19.60           20.20   20.171980   20.3150
# 181      20.20           20.00   20.061166   20.3200
# 182      20.00           20.10   20.099118   20.3250
# 183      20.10           19.90   20.061166   20.3300
# 184      19.90           19.90   19.898127   20.3300
# 185      19.90           19.90   20.099118   20.3350
# 186      19.90           20.10   20.910907   20.3300
# 187      20.10           20.30   21.688368   20.2900
# 188      20.30           20.10   21.411168   20.2200
# 189      20.10           19.50   21.494751   20.1550
# 190      19.50           19.60   21.619350   20.0550
# 191      19.60           20.90   20.994874   19.9500
# 192      20.90           20.50   20.565215   19.9450
# 193      20.50           19.90   20.161976   19.9500
# 194      19.90           19.80   19.998623   19.9450
# 195      19.80           20.10   19.898127   19.9400
# 196      20.10           20.00   19.859546   19.9550
# 197      20.00           19.90   19.557117   19.9700
# 198      19.90           19.60   19.758736   19.9950
# 199      19.60           19.50   19.697136   19.9950
# 200      19.50           18.80   20.272338   19.9900
# 201      18.80           18.70   20.004346   19.9200
# 202      18.70           18.60   20.089226   19.8550
# 203      18.60           18.30   19.895142   19.7800
# 204      18.30           18.20   19.826040   19.7000
# 205      18.20           18.40   19.826040   19.6150
# 206      18.40           18.10   20.025297   19.5400
# 207      18.10           18.50   20.224553   19.4400
# 208      18.50           18.70   20.089226   19.3500
# 209      18.70           18.50   19.510177   19.2800
# 210      18.50           18.70   19.610229   19.2300
# 211      18.70           18.70   20.822323   19.1850
# 212      18.70           18.70   20.423810   19.0750
# 213      18.70           18.50   19.904324   18.9850
# 214      18.50           18.40   19.795166   18.9150
# 215      18.40           18.50   20.025297   18.8450
# 216      18.50           18.30   19.989279   18.7650
# 217      18.30           18.00   19.826040   18.6800
# 218      18.00           18.20   19.527155   18.5850
# 219      18.20           18.20   19.495240   18.5150
# 220      18.20           18.40   18.867324   18.4500
# 221      18.40           18.40   18.792676   18.4300
# 222      18.40           18.80   18.692180   18.4150
# 223      18.80           19.60   18.448208   18.4250
# 224      19.60           19.50   18.422081   18.4900
# 225      19.50           19.10   18.619800   18.5550
# 226      19.10           19.00   18.313242   18.5900
# 227      19.00           19.10   18.649828   18.6350
# 228      19.10           19.40   18.851447   18.6650
# 229      19.40           19.60   18.717954   18.7000
# 230      19.60           20.00   18.920310   18.7550
# 231      20.00           19.80   18.923383   18.8200
# 232      19.80           19.90   18.923383   18.8750
# 233      19.90           20.20   18.725742   18.9350
# 234      20.20           20.10   18.653642   19.0200
# 235      20.10           20.10   18.726959   19.1050
# 236      20.10           20.50   18.552264   19.1850
# 237      20.50           20.90   18.313868   19.2950
# 238      20.90           21.00   18.517356   19.4400
# 239      21.00           21.00   18.523734   19.5800
# 240      21.00           21.00   18.720843   19.7200
# 241      21.00           21.20   18.720843   19.8500
# 242      21.20           21.80   19.127818   19.9900
# 243      21.80           21.50   19.941768   20.1400

# %% [markdown]
# # Basic LSTM

# %% [markdown]
# ## Create Model

# %%
seq_model = tf.keras.models.Sequential()

seq_model.add( tf.keras.layers.LSTM(units=150, input_shape=(None, 1) , return_sequences=True) ) # RNN Layer 1st
seq_model.add( tf.keras.layers.LSTM(units=150, input_shape=(None, 1) , return_sequences=False) ) # RNN Layer 2st
seq_model.add( tf.keras.layers.Dropout(0.3) ) #Dropout


#Use the defult 'linear activation'
seq_model.add( tf.keras.layers.Dense(1))

seq_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, None, 150)         91200
#
#  lstm_2 (LSTM)               (None, 150)               180600
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_1 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 271,951
# Trainable params: 271,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
os.system(f"rm *.hdf5")

optmiz = tf.keras.optimizers.Nadam(learning_rate=0.0001)
seq_model.compile(loss='mse', optimizer=optmiz, metrics=['mean_absolute_error','mean_squared_error'])

checkpoint = "seq_lstm_bestmodel_epoch{epoch:03d}.hdf5"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint, save_weights_only=False, monitor='val_loss', mode='min', save_best_only=True)

# %%
hist = seq_model.fit(x_train_norm, y_train_norm,
                  validation_data=(x_val_norm, y_val_norm),
                  batch_size=64, epochs=30,
                  callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/30
# 31/31 [==============================] - 4s 34ms/step - loss: 0.1121 - mean_absolute_error: 0.2842 - mean_squared_error: 0.1121 - val_loss: 0.0085 - val_mean_absolute_error: 0.0654 - val_mean_squared_error: 0.0085
# Epoch 2/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0098 - mean_absolute_error: 0.0767 - mean_squared_error: 0.0098 - val_loss: 0.0081 - val_mean_absolute_error: 0.0638 - val_mean_squared_error: 0.0081
# Epoch 3/30
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0091 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0091 - val_loss: 0.0076 - val_mean_absolute_error: 0.0621 - val_mean_squared_error: 0.0076
# Epoch 4/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0085 - mean_absolute_error: 0.0710 - mean_squared_error: 0.0085 - val_loss: 0.0072 - val_mean_absolute_error: 0.0603 - val_mean_squared_error: 0.0072
# Epoch 5/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0081 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0081 - val_loss: 0.0068 - val_mean_absolute_error: 0.0583 - val_mean_squared_error: 0.0068
# Epoch 6/30
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_absolute_error: 0.0669 - mean_squared_error: 0.0077 - val_loss: 0.0065 - val_mean_absolute_error: 0.0567 - val_mean_squared_error: 0.0065
# Epoch 7/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0075 - mean_absolute_error: 0.0662 - mean_squared_error: 0.0075 - val_loss: 0.0061 - val_mean_absolute_error: 0.0548 - val_mean_squared_error: 0.0061
# Epoch 8/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0070 - mean_absolute_error: 0.0633 - mean_squared_error: 0.0070 - val_loss: 0.0058 - val_mean_absolute_error: 0.0537 - val_mean_squared_error: 0.0058
# Epoch 9/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_absolute_error: 0.0625 - mean_squared_error: 0.0067 - val_loss: 0.0057 - val_mean_absolute_error: 0.0530 - val_mean_squared_error: 0.0057
# Epoch 10/30
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0064 - val_loss: 0.0054 - val_mean_absolute_error: 0.0516 - val_mean_squared_error: 0.0054
# Epoch 11/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0062 - val_loss: 0.0051 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0051
# Epoch 12/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_absolute_error: 0.0579 - mean_squared_error: 0.0059 - val_loss: 0.0050 - val_mean_absolute_error: 0.0496 - val_mean_squared_error: 0.0050
# Epoch 13/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0060 - val_loss: 0.0048 - val_mean_absolute_error: 0.0488 - val_mean_squared_error: 0.0048
# Epoch 14/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_absolute_error: 0.0583 - mean_squared_error: 0.0058 - val_loss: 0.0047 - val_mean_absolute_error: 0.0482 - val_mean_squared_error: 0.0047
# Epoch 15/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_absolute_error: 0.0571 - mean_squared_error: 0.0057 - val_loss: 0.0046 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0046
# Epoch 16/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_absolute_error: 0.0561 - mean_squared_error: 0.0056 - val_loss: 0.0047 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0047
# Epoch 17/30
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0051 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0051 - val_loss: 0.0049 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0049
# Epoch 18/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_absolute_error: 0.0542 - mean_squared_error: 0.0052 - val_loss: 0.0043 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0043
# Epoch 19/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_absolute_error: 0.0527 - mean_squared_error: 0.0049 - val_loss: 0.0043 - val_mean_absolute_error: 0.0464 - val_mean_squared_error: 0.0043
# Epoch 20/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0051 - val_loss: 0.0041 - val_mean_absolute_error: 0.0454 - val_mean_squared_error: 0.0041
# Epoch 21/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0049 - val_loss: 0.0041 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0041
# Epoch 22/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0049 - val_loss: 0.0040 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0040
# Epoch 23/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0048 - val_loss: 0.0040 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0040
# Epoch 24/30
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0046 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0046 - val_loss: 0.0042 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0042
# Epoch 25/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0048 - val_loss: 0.0040 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0040
# Epoch 26/30
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_absolute_error: 0.0503 - mean_squared_error: 0.0045 - val_loss: 0.0040 - val_mean_absolute_error: 0.0450 - val_mean_squared_error: 0.0040
# Epoch 27/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0045 - val_loss: 0.0037 - val_mean_absolute_error: 0.0426 - val_mean_squared_error: 0.0037
# Epoch 28/30
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0043 - val_loss: 0.0036 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0036
# Epoch 29/30
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0043 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0043 - val_loss: 0.0037 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0037
# Epoch 30/30
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0041 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0041 - val_loss: 0.0039 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0039

# %%
#Plot training and validation loss values
plt.figure(figsize=(25,5))

plt.subplot(121)
plt.plot( hist.history['loss'])
plt.plot( hist.history['val_loss'])
plt.title('Model loss mean squared error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train','val'], loc='upper right')

plt.subplot(122)
plt.plot( hist.history['mean_absolute_error'])
plt.plot( hist.history['val_mean_absolute_error'])
plt.title('Model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('Epoch')
plt.legend(['train','val'], loc='upper right')


plt.show()

# %% [markdown]
# ## Evaluate

# %%
# Load the model from the best epoch (minimum val_loss)
bestmodel_file = max([ f for f in os.listdir(".") if f.startswith('seq_lstm_bestmodel_') and f.endswith(".hdf5")])
print( f"The best model : {bestmodel_file}")
# Out:
# The best model : seq_lstm_bestmodel_epoch028.hdf5

# %%
seq_best = tf.keras.models.load_model(bestmodel_file, compile=True)

# %%
#Evaluate the model from last epoch
score = seq_model.evaluate(x_test_norm, y_test_norm, verbose=0)
if hasattr(score,'__len__'):
  print(f"Test results (model from the last epoch) :{[(seq_model.metrics_names[i],score[i]) for i in range(len(score))]}")
else :
   print(f"Test results (model from the last epoch) :{[(seq_model.metrics_names[0],score)]}")
# Out:
# Test results (model from the last epoch) :[('loss', 0.004943512380123138), ('mean_absolute_error', 0.05194740742444992), ('mean_squared_error', 0.004943512380123138)]

# %%
#Evaluate the model from best epoch
score = seq_best.evaluate(x_test_norm, y_test_norm, verbose=0)
if hasattr(score,'__len__'):
  print(f"Test results (model from the best epoch) :{[(seq_best.metrics_names[i],score[i]) for i in range(len(score))]}")
else :
   print(f"Test results (model from the best epoch) :{[(seq_best.metrics_names[0],score)]}")
# Out:
# Test results (model from the best epoch) :[('loss', 0.004416186828166246), ('mean_absolute_error', 0.05179224908351898), ('mean_squared_error', 0.004416186828166246)]

# %% [markdown]
# ## Inference

# %%
true_price = lst_y_close[2]

y_last_norm = seq_model.predict(x_test_norm).reshape(-1,1)
y_last_preds = norm_tool.inverse_transform(y_last_norm)
y_last_price = (lst_x_close[2][:,0].reshape(-1,1)*(1+y_last_preds))

y_best_norm = seq_best.predict(x_test_norm).reshape(-1,1)
y_best_preds = norm_tool.inverse_transform(y_best_norm)
y_best_price = (lst_x_close[2][:,0].reshape(-1,1)*(1+y_best_preds))

# %%
#Plot training and validation loss values
plt.figure(figsize=(15,5))
plt.plot( true_price)
plt.plot( y_last_price)
plt.plot( y_best_price)
plt.title('Deep learnin Predict vs True')
plt.ylabel('Price')
plt.xlabel('Time')
plt.legend(['True','last','best'], loc='upper right')
plt.show()

# %%
best_mse  = mean_squared_error(true_price,y_best_price)
best_mae  = mean_absolute_error(true_price,y_best_price)
last_mse  = mean_squared_error(true_price,y_last_price)
last_mae  = mean_absolute_error(true_price,y_last_price)

print(f"Best model mean_squared_error : {best_mse} ,mean_absolute_error : {best_mae}")
print(f"Last model mean_squared_error : {last_mse} ,mean_absolute_error : {last_mae}")
# Out:
# Best model mean_squared_error : 0.5441570160417538 ,mean_absolute_error : 0.5899383678055201
# Last model mean_squared_error : 0.5907342761635594 ,mean_absolute_error : 0.587584907634825

# %%
pd.set_option('display.max_rows', 500)

pd.DataFrame({"price_t20":lst_x_close[2][:,-1].ravel()
              ,"true_price_t21":true_price.ravel()
              ,"lgbm_price":lgbm_price.ravel()
              ,"move_avg":move_avg.ravel()
              ,"Stack LSTM":y_best_price.ravel()})
# Out:
#      price_t20  true_price_t21  lgbm_price  move_avg  Stack LSTM
# 0        15.20           15.20   14.569651   14.5050   14.904722
# 1        15.20           15.20   14.470823   14.5450   15.020420
# 2        15.20           15.20   14.369628   14.5900   15.120509
# 3        15.20           15.00   14.272980   14.6400   15.202263
# 4        15.00           14.80   14.070526   14.6850   15.258519
# 5        14.80           14.90   13.964850   14.7300   15.260215
# 6        14.90           14.90   14.453666   14.7850   15.191977
# 7        14.90           15.00   14.167239   14.8150   15.176140
# 8        15.00           14.70   14.554740   14.8650   15.112810
# 9        14.70           14.90   14.617433   14.8800   15.055752
# 10       14.90           14.80   14.617433   14.9000   15.009397
# 11       14.80           14.70   14.516623   14.9150   14.964684
# 12       14.70           14.60   14.772852   14.9300   14.904176
# 13       14.60           15.20   14.873347   14.9250   14.847520
# 14       15.20           16.10   14.670829   14.9450   14.838815
# 15       16.10           16.60   14.752838   15.0250   14.917023
# 16       16.60           16.90   15.261557   15.1300   15.079281
# 17       16.90           17.00   15.465044   15.2250   15.329075
# 18       17.00           16.80   15.668532   15.3150   15.623398
# 19       16.80           16.70   15.465044   15.3850   15.945306
# 20       16.70           16.60   15.409531   15.4600   16.225636
# 21       16.60           17.70   15.386475   15.5300   16.458707
# 22       17.70           19.10   15.470371   15.6550   16.726500
# 23       19.10           18.60   15.352198   15.8500   17.145070
# 24       18.60           18.40   15.147502   16.0300   17.593211
# 25       18.40           18.50   15.249850   16.2100   17.953556
# 26       18.50           18.10   15.249850   16.3900   18.296719
# 27       18.10           18.20   15.352198   16.5500   18.525310
# 28       18.20           18.30   15.045154   16.7100   18.773680
# 29       18.30           18.40   15.249850   16.8900   18.834951
# 30       18.40           18.20   15.147502   17.0650   18.922272
# 31       18.20           18.20   15.045154   17.2350   18.945556
# 32       18.20           18.20   14.942806   17.4100   18.918770
# 33       18.20           18.20   15.556894   17.5900   18.751855
# 34       18.20           18.40   16.380738   17.7400   18.574764
# 35       18.40           18.40   16.889456   17.8550   18.492006
# 36       18.40           18.20   17.107330   17.9450   18.449109
# 37       18.20           19.30   17.203076   18.0100   18.416588
# 38       19.30           19.60   17.092944   18.1250   18.482852
# 39       19.60           19.80   17.087397   18.2650   18.614892
# 40       19.80           19.80   16.989766   18.4200   18.809140
# 41       19.80           20.30   18.008637   18.5800   18.934644
# 42       20.30           20.50   19.328162   18.7100   19.106068
# 43       20.50           20.40   18.856399   18.7800   19.428968
# 44       20.40           20.40   18.720843   18.8700   19.730503
# 45       20.40           20.70   18.755021   18.9700   19.977076
# 46       20.70           20.30   18.415612   19.0800   20.273487
# 47       20.30           19.70   18.517356   19.1900   20.443745
# 48       19.70           20.10   18.523301   19.2650   20.511618
# 49       20.10           20.40   18.625732   19.3550   20.534140
# 50       20.40           20.30   18.517356   19.4550   20.579714
# 51       20.30           20.40   18.517356   19.5600   20.576536
# 52       20.40           20.20   18.517356   19.6700   20.567059
# 53       20.20           20.30   18.517356   19.7700   20.537192
# 54       20.30           20.60   18.653642   19.8750   20.486860
# 55       20.60           20.60   18.720843   19.9850   20.479203
# 56       20.60           21.20   18.517356   20.0950   20.500445
# 57       21.20           20.90   19.566049   20.2450   20.494316
# 58       20.90           20.70   19.834134   20.3250   20.565309
# 59       20.70           21.50   20.033270   20.3800   20.630825
# 60       21.50           21.80   20.042908   20.4650   20.751790
# 61       21.80           22.00   20.547706   20.5650   20.888212
# 62       22.00           21.80   20.750146   20.6500   21.077749
# 63       21.80           22.70   20.643691   20.7150   21.282489
# 64       22.70           23.50   20.755717   20.8300   21.531493
# 65       23.50           23.20   21.060948   20.9850   21.832952
# 66       23.20           23.70   20.653974   21.1100   22.217671
# 67       23.70           23.50   20.162553   21.2800   22.671077
# 68       23.50           23.60   20.486985   21.4700   22.955246
# 69       23.60           23.60   20.762867   21.6450   23.222810
# 70       23.60           24.60   20.661088   21.8050   23.507855
# 71       24.60           24.90   20.878989   22.0200   23.788416
# 72       24.90           25.25   20.674293   22.2450   24.145402
# 73       25.25           23.50   20.776641   22.4975   24.470561
# 74       23.50           23.30   20.959205   22.6575   24.600484
# 75       23.30           23.90   20.959205   22.7925   24.647707
# 76       23.90           24.00   21.569667   22.9575   24.549147
# 77       24.00           25.25   21.264436   23.0975   24.559363
# 78       25.25           26.00   21.186033   23.3150   24.627980
# 79       26.00           26.25   22.004817   23.5800   24.687300
# 80       26.25           25.75   22.311861   23.8175   24.910760
# 81       25.75           25.50   22.423566   24.0150   25.152832
# 82       25.50           25.75   22.219716   24.1900   25.409193
# 83       25.75           26.00   23.095823   24.3875   25.506502
# 84       26.00           26.00   23.909772   24.5525   25.622066
# 85       26.00           26.25   23.604541   24.6775   25.838402
# 86       26.25           25.50   24.113260   24.8300   25.953637
# 87       25.50           24.10   23.788300   24.9200   26.069469
# 88       24.10           24.50   23.791132   24.9500   25.978692
# 89       24.50           24.50   23.794629   24.9950   25.816228
# 90       24.50           24.50   24.721915   25.0400   25.548460
# 91       24.50           23.80   25.023402   25.0350   25.334006
# 92       23.80           23.90   25.263178   24.9800   25.082765
# 93       23.90           24.30   23.690322   24.9125   24.851435
# 94       24.30           24.10   23.574504   24.9525   24.602367
# 95       24.10           23.90   24.089552   24.9925   24.387330
# 96       23.90           24.80   24.118942   24.9925   24.209198
# 97       24.80           23.40   25.346727   25.0325   24.154834
# 98       23.40           23.40   25.903369   24.9400   24.084762
# 99       23.40           23.30   26.152440   24.8100   23.994189
# 100      23.30           22.80   25.654298   24.6625   23.864962
# 101      22.80           23.00   25.405227   24.5150   23.709386
# 102      23.00           22.80   25.654298   24.3900   23.571821
# 103      22.80           22.80   25.787749   24.2425   23.436931
# 104      22.80           22.70   25.787749   24.0825   23.301837
# 105      22.70           22.60   26.035708   23.9175   23.189252
# 106      22.60           22.50   25.303410   23.7350   23.035154
# 107      22.50           22.40   24.094117   23.5850   22.864786
# 108      22.40           22.70   24.408944   23.5000   22.755722
# 109      22.70           22.50   24.486867   23.4100   22.672279
# 110      22.50           22.00   24.408944   23.3100   22.605554
# 111      22.00           21.80   23.787242   23.1850   22.500138
# 112      21.80           22.00   23.811174   23.0850   22.395757
# 113      22.00           22.20   24.209687   22.9900   22.311758
# 114      22.20           21.90   24.087081   22.8850   22.234639
# 115      21.90           21.90   23.811174   22.7750   22.158794
# 116      21.90           21.50   24.597545   22.6750   22.130167
# 117      21.50           21.50   23.313032   22.5100   22.009634
# 118      21.50           22.60   23.313032   22.4150   21.917202
# 119      22.60           23.00   23.383439   22.3750   21.895975
# 120      23.00           22.30   22.984652   22.3600   21.948854
# 121      22.30           22.40   23.082365   22.3350   22.014722
# 122      22.40           22.30   22.912995   22.3050   22.089587
# 123      22.30           22.10   22.887341   22.2800   22.157327
# 124      22.10           21.60   22.781291   22.2450   22.203499
# 125      21.60           21.50   22.611795   22.1900   22.195677
# 126      21.50           21.60   22.511742   22.1350   22.142883
# 127      21.60           21.40   22.411690   22.0900   22.067942
# 128      21.40           21.20   22.711847   22.0400   21.966039
# 129      21.20           20.90   22.511742   21.9650   21.847963
# 130      20.90           21.00   22.011481   21.8850   21.698429
# 131      21.00           20.80   21.811377   21.8350   21.539014
# 132      20.80           20.40   22.011481   21.7850   21.376602
# 133      20.40           20.60   22.117492   21.7050   21.203225
# 134      20.60           20.50   21.911429   21.6250   21.034164
# 135      20.50           20.60   21.894654   21.5550   20.882678
# 136      20.60           20.40   21.511220   21.4900   20.745778
# 137      20.40           20.40   21.511220   21.4350   20.631105
# 138      20.40           20.30   22.516005   21.3800   20.580177
# 139      20.30           20.40   22.812239   21.2650   20.529146
# 140      20.40           21.10   22.217120   21.1350   20.446987
# 141      21.10           20.60   22.411690   21.0750   20.455606
# 142      20.60           20.60   22.288046   20.9850   20.468813
# 143      20.60           20.50   22.088153   20.9000   20.486842
# 144      20.50           20.30   21.611273   20.8200   20.497772
# 145      20.30           20.40   21.511220   20.7550   20.496243
# 146      20.40           20.30   21.611273   20.7000   20.490782
# 147      20.30           20.30   21.411168   20.6350   20.474688
# 148      20.30           20.20   21.211064   20.5800   20.451790
# 149      20.20           19.80   20.974845   20.5300   20.418940
# 150      19.80           20.20   21.010960   20.4750   20.350950
# 151      20.20           20.20   20.874487   20.4350   20.295125
# 152      20.20           19.90   20.501101   20.4050   20.249058
# 153      19.90           20.20   20.673770   20.3800   20.186770
# 154      20.20           20.20   20.601596   20.3600   20.147151
# 155      20.20           20.40   20.678914   20.3450   20.122025
# 156      20.40           20.40   20.501101   20.3350   20.125330
# 157      20.40           20.40   20.501101   20.3350   20.145023
# 158      20.40           20.00   20.400605   20.3350   20.178176
# 159      20.00           19.90   20.478148   20.3200   20.186979
# 160      19.90           20.10   21.111012   20.2950   20.172484
# 161      20.10           19.90   20.673770   20.2450   20.168266
# 162      19.90           20.00   20.673770   20.2100   20.141994
# 163      20.00           19.90   20.573412   20.1800   20.115191
# 164      19.90           19.80   20.377765   20.1500   20.082396
# 165      19.80           20.00   20.473054   20.1250   20.036037
# 166      20.00           20.90   20.400605   20.1050   20.003796
# 167      20.90           21.70   20.464406   20.1350   20.041640
# 168      21.70           21.40   20.446486   20.2050   20.185743
# 169      21.40           21.50   20.042908   20.2650   20.387324
# 170      21.50           21.70   20.441302   20.3500   20.584177
# 171      21.70           21.00   20.446486   20.4250   20.821066
# 172      21.00           20.40   20.134448   20.4650   21.025656
# 173      20.40           20.00   20.363596   20.4900   21.090036
# 174      20.00           19.90   20.300109   20.4800   21.075739
# 175      19.90           19.80   20.473054   20.4650   20.970526
# 176      19.80           19.70   20.473054   20.4350   20.823819
# 177      19.70           19.40   20.473054   20.4000   20.641142
# 178      19.40           19.60   20.071622   20.3500   20.433011
# 179      19.60           19.60   19.998623   20.3300   20.215900
# 180      19.60           20.20   20.171980   20.3150   20.018150
# 181      20.20           20.00   20.061166   20.3200   19.891863
# 182      20.00           20.10   20.099118   20.3250   19.810231
# 183      20.10           19.90   20.061166   20.3300   19.771628
# 184      19.90           19.90   19.898127   20.3300   19.752176
# 185      19.90           19.90   20.099118   20.3350   19.750557
# 186      19.90           20.10   20.910907   20.3300   19.772451
# 187      20.10           20.30   21.688368   20.2900   19.825750
# 188      20.30           20.10   21.411168   20.2200   19.879742
# 189      20.10           19.50   21.494751   20.1550   19.939413
# 190      19.50           19.60   21.619350   20.0550   19.958269
# 191      19.60           20.90   20.994874   19.9500   19.945074
# 192      20.90           20.50   20.565215   19.9450   20.005024
# 193      20.50           19.90   20.161976   19.9500   20.083458
# 194      19.90           19.80   19.998623   19.9450   20.120917
# 195      19.80           20.10   19.898127   19.9400   20.126565
# 196      20.10           20.00   19.859546   19.9550   20.129764
# 197      20.00           19.90   19.557117   19.9700   20.130401
# 198      19.90           19.60   19.758736   19.9950   20.096845
# 199      19.60           19.50   19.697136   19.9950   20.044987
# 200      19.50           18.80   20.272338   19.9900   19.959357
# 201      18.80           18.70   20.004346   19.9200   19.835936
# 202      18.70           18.60   20.089226   19.8550   19.668260
# 203      18.60           18.30   19.895142   19.7800   19.477836
# 204      18.30           18.20   19.826040   19.7000   19.263034
# 205      18.20           18.40   19.826040   19.6150   19.042061
# 206      18.40           18.10   20.025297   19.5400   18.853654
# 207      18.10           18.50   20.224553   19.4400   18.681805
# 208      18.50           18.70   20.089226   19.3500   18.537825
# 209      18.70           18.50   19.510177   19.2800   18.426069
# 210      18.50           18.70   19.610229   19.2300   18.372903
# 211      18.70           18.70   20.822323   19.1850   18.422268
# 212      18.70           18.70   20.423810   19.0750   18.419534
# 213      18.70           18.50   19.904324   18.9850   18.430555
# 214      18.50           18.40   19.795166   18.9150   18.456313
# 215      18.40           18.50   20.025297   18.8450   18.481265
# 216      18.50           18.30   19.989279   18.7650   18.496953
# 217      18.30           18.00   19.826040   18.6800   18.496856
# 218      18.00           18.20   19.527155   18.5850   18.463836
# 219      18.20           18.20   19.495240   18.5150   18.424383
# 220      18.20           18.40   18.867324   18.4500   18.381887
# 221      18.40           18.40   18.792676   18.4300   18.348197
# 222      18.40           18.80   18.692180   18.4150   18.327678
# 223      18.80           19.60   18.448208   18.4250   18.348609
# 224      19.60           19.50   18.422081   18.4900   18.449260
# 225      19.50           19.10   18.619800   18.5550   18.587963
# 226      19.10           19.00   18.313242   18.5900   18.741584
# 227      19.00           19.10   18.649828   18.6350   18.843160
# 228      19.10           19.40   18.851447   18.6650   18.940746
# 229      19.40           19.60   18.717954   18.7000   19.061263
# 230      19.60           20.00   18.920310   18.7550   19.166909
# 231      20.00           19.80   18.923383   18.8200   19.312474
# 232      19.80           19.90   18.923383   18.8750   19.452899
# 233      19.90           20.20   18.725742   18.9350   19.603394
# 234      20.20           20.10   18.653642   19.0200   19.754906
# 235      20.10           20.10   18.726959   19.1050   19.876703
# 236      20.10           20.50   18.552264   19.1850   20.010108
# 237      20.50           20.90   18.313868   19.2950   20.163923
# 238      20.90           21.00   18.517356   19.4400   20.292002
# 239      21.00           21.00   18.523734   19.5800   20.462214
# 240      21.00           21.00   18.720843   19.7200   20.611167
# 241      21.00           21.20   18.720843   19.8500   20.772921
# 242      21.20           21.80   19.127818   19.9900   20.885136
# 243      21.80           21.50   19.941768   20.1400   20.996375

# %% [markdown]
# 1.   https://github.com/borisbanushev/stockpredictionai
# 2.   https://www.datacamp.com/community/tutorials/lstm-python-stock-market
# 3.   https://docs.google.com/spreadsheets/d/15g1n16B21J5oIEeV6TwhlSKvNdG7IiqSq-mOoMT6p4M/edit#gid=504220406
